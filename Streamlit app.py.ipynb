# %%
import streamlit as st
import numpy as np
import joblib

# %%
import os
os.chdir("C:\\Users\\sugku\\Data Science with Onur\\Project 5_Predicting Student Exam Scores with ML\\Predicting-Student-Performance-Based-on-Habits")

# %%
model = joblib.load("best_model.pkl")
# This line: 👉 Loads your saved trained model 👉 Stores it in variable model 👉 Makes it ready for prediction

st.title("Student Exam Score Predictor")
# Out:
# 2026-02-23 21:55:35.515 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 21:55:35.516 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 21:55:35.517 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
# Let include an input fields
study_hours = st.slider("Study Hours per Day", 0.0, 12.0, 2.0) # 0.0 is min value, 12.0 is max value, & 2.0 is base value
attendance = st.slider("Attendance Percentage", 0.0, 100.0, 80.0)
mental_health = st.slider("Mental Health Rating (1-10)", 1, 10, 5)
sleep_hours = st.slider("Sleep Hours per Night", 0.0, 12.0, 7.0)
part_time_job = st.selectbox("Part-Time Job", ["No", "Yes"])
# Out:
# 2026-02-23 21:55:35.532 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 21:55:35.534 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 21:55:35.535 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 21:55:35.537 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 21:55:35.538 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 21:55:35.541 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 21:55:35.546 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 21:55:35.552 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 21:55:35.557 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 21:55:35.562 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 21:55:35.567 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 21:55:35.572 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 21:55:35.588 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 21:55:35.597 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 21:55:35.612 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 21:55:35.617 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 21:55:35.627 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 21:55:35.635 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 21:55:35.639 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 21:55:35.645 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 21:55:35.650 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 21:55:35.658 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 21:55:35.665 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 21:55:35.677 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 21:55:35.687 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 21:55:35.694 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 21:55:35.700 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 21:55:35.705 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 21:55:35.710 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 21:55:35.715 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 21:55:35.722 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# ptj = part time job
# In our model we have used part time job as 0 and 1, so lets change it to yes and no
ptj_encoded = 1 if part_time_job == "Yes" else 0

# %%
if st.button("Predict Exam Score"):

    input_data = np.array([[study_hours, attendance, mental_health, sleep_hours, ptj_encoded]]) # used encoded part time job
    prediction = model.predict(input_data)[0]
    # Why [0]? Because model.predict() returns array like array([78.45321]) --> So [0] extracts the number.

    # We need to cap between 0 to 100, becoz the score shouldn't beyong this range
    prediction = max(0, min(100, prediction))

    st.success(f"Predicted Exam Score: {prediction: .2f}") # Our model is ready right now

# st.button("Predict Exam Score") --> This means: 👉 When user clicks button & 👉 Run everything inside this block
# Out:
# 2026-02-23 22:05:29.935 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 22:05:29.936 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 22:05:29.938 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 22:05:29.939 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 22:05:29.939 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-23 22:05:29.940 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# ✔ Full ML pipeline
#
# ✔ Hyperparameter tuning
#
# ✔ Model comparison
#
# ✔ Best model selection
#
# ✔ Model saving
#
# ✔ Model loading
#
# ✔ Streamlit integration
#
# ✔ Production-safe prediction
